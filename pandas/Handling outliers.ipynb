# %% [markdown]
# ## Handling outliers

# %%
import pandas as pd
titanic_df = pd.read_csv("Titanic_data.csv")

# %%
#using IQR

# %%
titanic_df.Age.plot.box()
# Out:
# <Axes: >

# %%
Q1=titanic_df.Age.quantile(q=0.25)
Q3=titanic_df.Age.quantile(q=0.75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

print(upper_limit, lower_limit)
# Out:
# 64.8125 -6.6875

# %%
titanic_df[(titanic_df.Age < upper_limit) & (titanic_df.Age> lower_limit)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df[(titanic_df.Age > upper_limit) | (titanic_df.Age< lower_limit)] #> number outliers
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 280          281         0       3                      Duane, Mr. Frank
# 456          457         0       1             Millet, Mr. Francis Davis
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ## Using z-score

# %%
z_score_thres = 2.5
age_mean = titanic_df.Age.mean()
age_std = titanic_df.Age.std()
z_score = abs(( titanic_df.Age - age_mean) / (age_std))


titanic_df["Z-score"] = z_score

z_score
# Out:
# 0      0.530005
# 1      0.571430
# 2      0.254646
# 3      0.364911
# 4      0.364911
#          ...
# 886    0.185807
# 887    0.736524
# 888         NaN
# 889    0.254646
# 890    0.158392
# Name: Age, Length: 891, dtype: float64

# %%
titanic_df[titanic_df["Z-score"]> z_score_thres]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked   Z-score
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C  2.843141
# 116  male  70.5      0      0      370369   7.7500   NaN        Q  2.808721
# 493  male  71.0      0      0    PC 17609  49.5042   NaN        C  2.843141
# 630  male  80.0      0      0       27042  30.0000   A23        S  3.462699
# ...

# %%
#import scipy
# z_score= scipy.stats.z_score(titanic_df
