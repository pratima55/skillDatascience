# %%
import pandas as pd
titanic_df = pd.read_csv("Titanic_data.csv")

# %%
#!pip install matplotlib
# !pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
#     --------------------------------------- 0.8/41.0 MB 7.8 MB/s eta 0:00:06
#    ------- -------------------------------- 7.3/41.0 MB 24.3 MB/s eta 0:00:02
#    -------------- ------------------------- 14.9/41.0 MB 30.5 MB/s eta 0:00:01
#    -------------------- ------------------- 20.7/41.0 MB 29.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 29.4/41.0 MB 32.0 MB/s eta 0:00:01
#    -------------------------------------- - 39.8/41.0 MB 35.5 MB/s eta 0:00:01
#    ---------------------------------------- 41.0/41.0 MB 30.8 MB/s eta 0:00:00
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/scipy/
# ...

# %% [markdown]
# ## 1. Bar graph

# %%
titanic_df["Survived"].value_counts().plot(
    kind = "bar", legend = True, figsize = (4,4),
    title = "count of survived Passengers",
    grid = True,
    fontsize = 10,
    colormap = "Dark2"
)
# Out:
# <Axes: title={'center': 'count of survived Passengers'}, xlabel='Survived'>

# %%
group_by_gender= titanic_df[["Sex", "Survived"]].groupby(by = "Sex")
group_by_gender.value_counts().plot(
    kind = "bar",
    colormap = "Dark2",
    grid = True
)
# Out:
# <Axes: xlabel='Sex,Survived'>

# %%
 group_by_embarked= titanic_df[[ "Age", "Embarked"]].groupby(by = "Embarked")
group_by_embarked.mean().plot(
    kind = "bar",
    grid = True,
    colormap = "Dark2"
)
# Out:
# <Axes: xlabel='Embarked'>

# %%
ax= titanic_df[[ "Age", "Embarked"]].groupby(by = "Embarked")
ax

# %% [markdown]
# ## 2. Pie Chart

# %%
#ax= titanic_df[[ "Age", "Embarked"]].groupby(by = "Embarked").value_counts(normalize = True).plot(kind = "pie")
#ax.mean().plot(
   # kind = "bar",

#)
#ax.set_xticklabels(["Port A", "Port B", "PortC"], rotation = 45)

# %%
ax= titanic_df[[ "Age", "Embarked"]].groupby(by = "Embarked").mean().plot(kind = "pie", subplots = True, colormap = "Pastel1")

# %% [markdown]
# ## 3. Line Graph

# %% [markdown]
# titanic_df.loc[:10, "Age"].plot(kind = "line")

# %%
titanic_df.loc[:10, "Fare"].plot(kind = "line")
# Out:
# <Axes: >

# %% [markdown]
# ## 4. Scatter Plot(x,y)

# %%
titanic_df.plot.scatter("Age","Fare")
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# ## 5. Histogram

# %%
import numpy as np
np.linspace(0,80,10)
# Out:
# array([ 0.        ,  8.88888889, 17.77777778, 26.66666667, 35.55555556,
#        44.44444444, 53.33333333, 62.22222222, 71.11111111, 80.        ])

# %%
titanic_df.Age.plot.hist(bins = 8, grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
titanic_df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
titanic_df.Age.plot.kde(ind = np.linspace(0,80,500))
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## 6. Box Plots

# %%
titanic_df.plot.box(column = "Age", by="Sex")
# Out:
# Age    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# ## 7. Heatmap

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
correlation = titanic_df[["Pclass","Age","Fare","SibSp"]].corr()
correlation
# Out:
#           Pclass       Age      Fare     SibSp
# Pclass  1.000000 -0.369226 -0.549500  0.083081
# Age    -0.369226  1.000000  0.096067 -0.308247
# Fare   -0.549500  0.096067  1.000000  0.159651
# SibSp   0.083081 -0.308247  0.159651  1.000000

# %%
sns.heatmap(correlation, annot = True , cmap ="coolwarm")
# Out:
# <Axes: >
